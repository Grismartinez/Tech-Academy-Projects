# %%
# Imports
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
# Load dataset
# seaborn has built-in datasets like "diamonds"
diamonds = sns.load_dataset('diamonds')

# %%
price = diamonds['price']

# %%
# Univariate Analysis
# Univariate analysis examines ONE variable at a time
# I chose the variable 'price' to analyze its distribution

plt.figure()

# Histogram of diamond prices
plt.hist(df['price'], bins=20)

# Add labels and title
plt.title('Distribution of Diamond Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')

# Show plot
plt.show()

# %%
# Multivariate analysis examines relationships between TWO or more variables
# I chose 'carat' (weight) and 'price' to analyze their relationship

plt.figure()

# Scatter plot showing relationship between carat and price
plt.scatter(df.diamonds['carat'], df.diamonds['price'])

# Add labels and title
plt.title('Carat vs Price Relationship')
plt.xlabel('Carat')
plt.ylabel('Price')

# Show plot
plt.show()

# %%
# Summary statistics
price_summary = price.describe()
price_median = price.median()
price_mode = price.mode().iloc[0]
price_skew = price.skew()
price_kurt = price.kurtosis()
print("Price summary:\n", price_summary)
print("Median:", price_median, "Mode:", price_mode, "Skewness:", price_skew, "Kurtosis:", price_kurt)
# Out:
# Price summary:
#  count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64
# Median: 2401.0 Mode: 605 Skewness: 1.618395283383529 Kurtosis: 2.17769575924869

# %%
# Explanation of Analysis

# Univariate Analysis:
# I selected 'price' to understand how diamond prices are distributed.
# The histogram helps identify patterns such as skewness and spread.

# Multivariate Analysis:
# I selected 'carat' and 'price' to examine their relationship.
# The scatter plot shows that as carat increases, price generally increases,
# indicating a positive correlation between the two variables.
