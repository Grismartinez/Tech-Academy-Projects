# %%
import pandas as pd
from metplolib import pyplot as plt

# %%
data = pd.read_csv('coutries.csv')
data.head()

# %%
set(data.continent)

# %%
data_2007 = data[data.year == 2007]

# %%
asia_2007[data_2207.continent] == 'Asia']
europe_2007 = data_2007 (data_2007.continent == 'europe']

# %%
asia_2007.hea()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 asia_2007.hea()
#
# NameError: name 'asia_2007' is not defined
