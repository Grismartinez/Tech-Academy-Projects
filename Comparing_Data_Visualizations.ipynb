# %%
import pandas as pd
from matplolib import pyplot as plt
# pandas is used to load and manipulate data
# matplotlib.pyplot is used for creating visualizations
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_610/2547046515.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 from matplolib import pyplot as plt
#
# ModuleNotFoundError: No module named 'matplolib'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
data = pd.read_csv('Downloads/countries.csv')
data.head()

# %%
set(data.continent)

# %%
data_1952 = data[data.year == 1952]
# Filter data for the year 1952
# We only want data from the year 1952 for comparison

# %%
asia_1952 = data_1952[data_1952.continent == 'Asia']
africa_1952 = data_1952 [data_1952.continent == 'Africa']

# %%
asia_1952.head()
africa_1952.head()

# %%
plt.hist(asia_1952,africa_1952)
plt.subplots_adjust(hspace=0.5)
plt.show()
# Create histograms using subplots
# We use subplot() to display multiple graphs in one figure
# 1 row, 2 columns → first plot (Asia), second plot (Africa)
plt.figure(figsize=(12, 5))

# Histogram for Asia
# hist() creates a histogram of life expectancy values
plt.subplot(1, 2, 1)
plt.hist(asia['lifeExp'], bins=10)
plt.title('Life Expectancy in Asia (1952)')
plt.xlabel('Life Expectancy')
plt.ylabel('Frequency')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_610/3911452634.py in <cell line: 0>()
# ----> 1 plt.hist(asia_1952,africa_1952)
#       2 plt.subplots_adjust(hspace=0.5)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
# Histogram for Africa
# Second subplot for Africa to compare distributions
plt.subplot(1, 2, 2)
plt.hist(africa['lifeExp'], bins=10)
plt.title('Life Expectancy in Africa (1952)')
plt.xlabel('Life Expectancy')
plt.ylabel('Frequency')

# %%
# Adjust layout and display plots
# tight_layout() prevents overlapping of titles and labels
plt.tight_layout()
plt.show()
